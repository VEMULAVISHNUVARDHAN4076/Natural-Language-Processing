# %% [markdown]
# <a href="https://colab.research.google.com/github/VEMULAVISHNUVARDHAN4076/Natural-Language-Processing/blob/main/NLP_Lab_Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
SRUniversity = """The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indian largest Technology Business Incubator (TBI) in tier 2 cities."""

# %%
SRUniversity
# Out:
# 'The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana.\nIt is in 150 acres, with both separate hostel facilities for boys and girls.\nThere is a huge central library along with Indian largest Technology Business Incubator (TBI) in tier 2 cities.'

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
word_tokenize(SRUniversity)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['The',
#  'SR',
#  'University',
#  'campus',
#  'is',
#  'located',
#  'in',
#  'Ananthasagar',
#  'village',
#  'of',
#  'Hasanparthy',
#  'Mandal',
#  'in',
#  'Warangal',
#  ',',
#  'Telangana',
#  '.',
#  'It',
#  'is',
#  'in',
#  '150',
#  'acres',
#  ',',
#  'with',
#  'both',
#  'separate',
#  'hostel',
#  'facilities',
#  'for',
#  'boys',
#  'and',
#  'girls',
#  '.',
#  'There',
#  'is',
#  'a',
#  'huge',
#  'central',
#  'library',
#  'along',
#  'with',
#  'Indian',
#  'largest',
#  'Technology',
#  'Business',
#  'Incubator',
#  '(',
#  'TBI',
#  ')',
#  'in',
#  'tier',
#  '2',
#  'cities',
#  '.']

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(SRUniversity)
# Out:
# ['The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana.',
#  'It is in 150 acres, with both separate hostel facilities for boys and girls.',
#  'There is a huge central library along with Indian largest Technology Business Incubator (TBI) in tier 2 cities.']

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords
words_in_quote = word_tokenize(SRUniversity)
words_in_quote
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['The',
#  'SR',
#  'University',
#  'campus',
#  'is',
#  'located',
#  'in',
#  'Ananthasagar',
#  'village',
#  'of',
#  'Hasanparthy',
#  'Mandal',
#  'in',
#  'Warangal',
#  ',',
#  'Telangana',
#  '.',
#  'It',
#  'is',
#  'in',
#  '150',
#  'acres',
#  ',',
#  'with',
#  'both',
#  'separate',
#  'hostel',
#  'facilities',
#  'for',
#  'boys',
#  'and',
#  'girls',
#  '.',
#  'There',
#  'is',
#  'a',
#  'huge',
#  'central',
#  'library',
#  'along',
#  'with',
#  'Indian',
#  'largest',
#  'Technology',
#  'Business',
#  'Incubator',
#  '(',
#  'TBI',
#  ')',
#  'in',
#  'tier',
#  '2',
#  'cities',
#  '.']

# %%
stop_words = set(stopwords.words("english"))
filtered_list = []
for word in words_in_quote:
  if word.casefold() not in stop_words:
    filtered_list.append(word)
filtered_list
# Out:
# ['SR',
#  'University',
#  'campus',
#  'located',
#  'Ananthasagar',
#  'village',
#  'Hasanparthy',
#  'Mandal',
#  'Warangal',
#  ',',
#  'Telangana',
#  '.',
#  '150',
#  'acres',
#  ',',
#  'separate',
#  'hostel',
#  'facilities',
#  'boys',
#  'girls',
#  '.',
#  'huge',
#  'central',
#  'library',
#  'along',
#  'Indian',
#  'largest',
#  'Technology',
#  'Business',
#  'Incubator',
#  '(',
#  'TBI',
#  ')',
#  'tier',
#  '2',
#  'cities',
#  '.']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
stemmer = PorterStemmer()
words = word_tokenize(SRUniversity)
stemmed_words = [stemmer.stem(word) for word in words]
stemmed_words
# Out:
# ['the',
#  'sr',
#  'univers',
#  'campu',
#  'is',
#  'locat',
#  'in',
#  'ananthasagar',
#  'villag',
#  'of',
#  'hasanparthi',
#  'mandal',
#  'in',
#  'warang',
#  ',',
#  'telangana',
#  '.',
#  'it',
#  'is',
#  'in',
#  '150',
#  'acr',
#  ',',
#  'with',
#  'both',
#  'separ',
#  'hostel',
#  'facil',
#  'for',
#  'boy',
#  'and',
#  'girl',
#  '.',
#  'there',
#  'is',
#  'a',
#  'huge',
#  'central',
#  'librari',
#  'along',
#  'with',
#  'indian',
#  'largest',
#  'technolog',
#  'busi',
#  'incub',
#  '(',
#  'tbi',
#  ')',
#  'in',
#  'tier',
#  '2',
#  'citi',
#  '.']

# %%
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer(language='english')
words = word_tokenize(SRUniversity)
for word in words:
    print(word,"--->",snowball.stem(word))
# Out:
# The ---> the
# SR ---> sr
# University ---> univers
# campus ---> campus
# is ---> is
# located ---> locat
# in ---> in
# Ananthasagar ---> ananthasagar
# village ---> villag
# of ---> of
# Hasanparthy ---> hasanparthi
# Mandal ---> mandal
# in ---> in
# Warangal ---> warang
# , ---> ,
# Telangana ---> telangana
# . ---> .
# It ---> it
# is ---> is
# in ---> in
# 150 ---> 150
# acres ---> acr
# , ---> ,
# with ---> with
# both ---> both
# separate ---> separ
# hostel ---> hostel
# facilities ---> facil
# for ---> for
# boys ---> boy
# and ---> and
# girls ---> girl
# . ---> .
# There ---> there
# is ---> is
# a ---> a
# huge ---> huge
# central ---> central
# library ---> librari
# along ---> along
# with ---> with
# Indian ---> indian
# largest ---> largest
# Technology ---> technolog
# Business ---> busi
# Incubator ---> incub
# ( ---> (
# TBI ---> tbi
# ) ---> )
# in ---> in
# tier ---> tier
# 2 ---> 2
# cities ---> citi
# . ---> .

# %%
from nltk import LancasterStemmer
Lanc = LancasterStemmer()
words = word_tokenize(SRUniversity)
for word in words:
    print(word,"--->",Lanc.stem(word))
# Out:
# The ---> the
# SR ---> sr
# University ---> univers
# campus ---> camp
# is ---> is
# located ---> loc
# in ---> in
# Ananthasagar ---> ananthasag
# village ---> vil
# of ---> of
# Hasanparthy ---> hasanparthy
# Mandal ---> mand
# in ---> in
# Warangal ---> warang
# , ---> ,
# Telangana ---> telangan
# . ---> .
# It ---> it
# is ---> is
# in ---> in
# 150 ---> 150
# acres ---> acr
# , ---> ,
# with ---> with
# both ---> both
# separate ---> sep
# hostel ---> hostel
# facilities ---> facil
# for ---> for
# boys ---> boy
# and ---> and
# girls ---> girl
# . ---> .
# There ---> ther
# is ---> is
# a ---> a
# huge ---> hug
# central ---> cent
# library ---> libr
# along ---> along
# with ---> with
# Indian ---> ind
# largest ---> largest
# Technology ---> technolog
# Business ---> busy
# Incubator ---> incub
# ( ---> (
# TBI ---> tbi
# ) ---> )
# in ---> in
# tier ---> tier
# 2 ---> 2
# cities ---> city
# . ---> .

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
words = word_tokenize(SRUniversity)
for word in words:
    print(word,"--->",lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# The ---> The
# SR ---> SR
# University ---> University
# campus ---> campus
# is ---> is
# located ---> located
# in ---> in
# Ananthasagar ---> Ananthasagar
# village ---> village
# of ---> of
# Hasanparthy ---> Hasanparthy
# Mandal ---> Mandal
# in ---> in
# Warangal ---> Warangal
# , ---> ,
# Telangana ---> Telangana
# . ---> .
# It ---> It
# is ---> is
# in ---> in
# 150 ---> 150
# acres ---> acre
# , ---> ,
# with ---> with
# both ---> both
# separate ---> separate
# hostel ---> hostel
# facilities ---> facility
# for ---> for
# boys ---> boy
# and ---> and
# girls ---> girl
# . ---> .
# There ---> There
# is ---> is
# a ---> a
# huge ---> huge
# central ---> central
# library ---> library
# along ---> along
# with ---> with
# Indian ---> Indian
# largest ---> largest
# Technology ---> Technology
# ...

# %%
lemmatizer.lemmatize("worst")
# Out:
# 'worst'

# %%
lemmatizer.lemmatize("worst", pos="a")
# Out:
# 'bad'

# %%
medical_text = """
The patient was diagnosed with diabetes and hypertension.
He is receiving insulin injections and antihypertensive medication.
Doctors are monitoring blood glucose levels and cardiac conditions.
"""

# %%
# !pip install nltk spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 89.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import nltk
import spacy

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
nlp = spacy.load("en_core_web_sm")

# %%
from nltk.tokenize import sent_tokenize

sentences_nltk = sent_tokenize(medical_text)
print("\nNLTK Sentence Tokens:")
print(sentences_nltk)
# Out:
# NLTK Sentence Tokens:
# ['\nThe patient was diagnosed with diabetes and hypertension.', 'He is receiving insulin injections and antihypertensive medication.', 'Doctors are monitoring blood glucose levels and cardiac conditions.']

# %%
from nltk.tokenize import word_tokenize

words_nltk = word_tokenize(medical_text)
print("\nNLTK Word Tokens:")
print(words_nltk)
# Out:
# NLTK Word Tokens:
# ['The', 'patient', 'was', 'diagnosed', 'with', 'diabetes', 'and', 'hypertension', '.', 'He', 'is', 'receiving', 'insulin', 'injections', 'and', 'antihypertensive', 'medication', '.', 'Doctors', 'are', 'monitoring', 'blood', 'glucose', 'levels', 'and', 'cardiac', 'conditions', '.']

# %%
doc = nlp(medical_text)

sentences_spacy = [sent.text for sent in doc.sents]
words_spacy = [token.text for token in doc]

print("spaCy Sentence Tokens:")
print(sentences_spacy)

print("\nspaCy Word Tokens:")
print(words_spacy)
# Out:
# spaCy Sentence Tokens:
# ['\nThe patient was diagnosed with diabetes and hypertension.\n', 'He is receiving insulin injections and antihypertensive medication.\n', 'Doctors are monitoring blood glucose levels and cardiac conditions.\n']
#
# spaCy Word Tokens:
# ['\n', 'The', 'patient', 'was', 'diagnosed', 'with', 'diabetes', 'and', 'hypertension', '.', '\n', 'He', 'is', 'receiving', 'insulin', 'injections', 'and', 'antihypertensive', 'medication', '.', '\n', 'Doctors', 'are', 'monitoring', 'blood', 'glucose', 'levels', 'and', 'cardiac', 'conditions', '.', '\n']

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in words_nltk]
print("Stemmed Words:")
print(stemmed_words)
# Out:
# Stemmed Words:
# ['the', 'patient', 'wa', 'diagnos', 'with', 'diabet', 'and', 'hypertens', '.', 'he', 'is', 'receiv', 'insulin', 'inject', 'and', 'antihypertens', 'medic', '.', 'doctor', 'are', 'monitor', 'blood', 'glucos', 'level', 'and', 'cardiac', 'condit', '.']

# %%
lemmatized_words = [token.lemma_ for token in doc]
print("Lemmatized Words:")
print(lemmatized_words)
# Out:
# Lemmatized Words:
# ['\n', 'the', 'patient', 'be', 'diagnose', 'with', 'diabete', 'and', 'hypertension', '.', '\n', 'he', 'be', 'receive', 'insulin', 'injection', 'and', 'antihypertensive', 'medication', '.', '\n', 'doctor', 'be', 'monitor', 'blood', 'glucose', 'level', 'and', 'cardiac', 'condition', '.', '\n']

# %%
sample_text = """NLP models are transforming the world rapidly!"""

# %%
import nltk
nltk.download("punkt_tab")
from nltk.tokenize import word_tokenize

words_sample_text = word_tokenize(sample_text)
print(f"Word Tokens in sample text: \n{words_sample_text}")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# Word Tokens in sample text:
# ['NLP', 'models', 'are', 'transforming', 'the', 'world', 'rapidly', '!']
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmed_words_sample_text = [stemmer.stem(words) for words in words_sample_text]
print(f"Stemmed Words in Sample Text: \n{stemmed_words_sample_text}")
# Out:
# Stemmed Words in Sample Text:
# ['nlp', 'model', 'are', 'transform', 'the', 'world', 'rapidli', '!']

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmatized_words_sample_text = [lemmatizer.lemmatize(words) for words in words_sample_text]
print(f"Lemmatized Words in Sample Text: \n{lemmatized_words_sample_text}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Lemmatized Words in Sample Text:
# ['NLP', 'model', 'are', 'transforming', 'the', 'world', 'rapidly', '!']
